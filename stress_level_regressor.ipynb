# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# | 컬럼명                     | 설명                            |
# |---------------------------|---------------------------------|
# | ID                        | 샘플별 고유 ID                   |
# | gender                    | 성별                             |
# | age                       | 연령                             |
# | height                    | 키 (cm)                          |
# | weight                    | 몸무게 (kg)                      |
# | cholesterol               | 콜레스테롤 수치                  |
# | systolic_blood_pressure   | 수축기 혈압                      |
# | diastolic_blood_pressure  | 이완기 혈압                      |
# | glucose                   | 혈당 수치 (mg/dL)               |
# | bone_density              | 골밀도 (g/cm²)                   |
# | activity                  | 생활 시 운동 강도                |
# | smoke_status              | 흡연 상태                        |
# | medical_history           | 만성질환                         |
# | family_medical_history    | 가족력                           |
# | sleep_pattern             | 수면 패턴                        |
# | edu_level                 | 학력                             |
# | mean_working              | 1주일당 평균 근로 시간           |
# | stress_score              | **(TARGET)** 스트레스 점수       |

# %%
train = pd.read_csv("./data1/train.csv")
test = pd.read_csv("./data1/test.csv")

train
# Out:
#               ID gender  age  height  weight  cholesterol  \
# 0     TRAIN_0000      F   72  161.49   58.47       279.84
# 1     TRAIN_0001      M   88  179.87   77.60       257.37
# 2     TRAIN_0002      M   47  182.47   89.93       226.66
# 3     TRAIN_0003      M   69  185.78   68.63       206.74
# 4     TRAIN_0004      F   81  164.63   71.53       255.92
# ...          ...    ...  ...     ...     ...          ...
# 2995  TRAIN_2995      F   87  174.43   77.14       233.31
# 2996  TRAIN_2996      M   25  171.44   51.67       196.89
# 2997  TRAIN_2997      F   54  162.13   55.54       210.52
# 2998  TRAIN_2998      M   70  181.32   82.20       234.10
# 2999  TRAIN_2999      M   86  179.46   69.31       254.63
#
#       systolic_blood_pressure  diastolic_blood_pressure  glucose  \
# 0                         165                       100   143.35
# 1                         178                       111   146.94
# 2                         134                        95   142.61
# 3                         158                        92   137.26
# 4                         171                       116   129.37
# ...                       ...                       ...      ...
# 2995                      176                       111   134.71
# 2996                      143                        86   111.91
# 2997                      164                        91   136.47
# 2998                      182                        91   144.89
# 2999                      149                        94   154.92
#
#       bone_density  activity    smoke_status      medical_history  \
# 0             0.87  moderate       ex-smoker  high blood pressure
# 1             0.07  moderate       ex-smoker                  NaN
# 2             1.18     light       ex-smoker                  NaN
# 3             0.48   intense       ex-smoker  high blood pressure
# 4             0.34  moderate       ex-smoker             diabetes
# ...            ...       ...             ...                  ...
# 2995          0.20     light      non-smoker                  NaN
# 2996          1.75  moderate  current-smoker                  NaN
# 2997          0.80     light  current-smoker                  NaN
# 2998          0.58  moderate      non-smoker                  NaN
# 2999          0.45  moderate       ex-smoker  high blood pressure
#
#      family_medical_history     sleep_pattern            edu_level  \
# 0                  diabetes  sleep difficulty     bachelors degree
# 1                  diabetes            normal      graduate degree
# 2                       NaN            normal  high school diploma
# 3                       NaN      oversleeping      graduate degree
# 4                  diabetes  sleep difficulty     bachelors degree
# ...                     ...               ...                  ...
# 2995                    NaN      oversleeping                  NaN
# 2996                    NaN            normal  high school diploma
# 2997                    NaN            normal                  NaN
# 2998                    NaN      oversleeping  high school diploma
# 2999          heart disease            normal                  NaN
#
#       mean_working  stress_score
# 0              NaN          0.63
# 1              NaN          0.83
# 2              9.0          0.70
# 3              NaN          0.17
# 4              NaN          0.36
# ...            ...           ...
# 2995           NaN          0.02
# 2996           9.0          0.16
# 2997           9.0          0.16
# 2998           NaN          0.18
# 2999           NaN          0.04
#
# [3000 rows x 18 columns]

# %%
train.isnull().sum()
# Out:
# ID                             0
# gender                         0
# age                            0
# height                         0
# weight                         0
# cholesterol                    0
# systolic_blood_pressure        0
# diastolic_blood_pressure       0
# glucose                        0
# bone_density                   0
# activity                       0
# smoke_status                   0
# medical_history             1289
# family_medical_history      1486
# sleep_pattern                  0
# edu_level                    607
# mean_working                1032
# stress_score                   0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        3000 non-null   object
#  1   gender                    3000 non-null   object
#  2   age                       3000 non-null   int64
#  3   height                    3000 non-null   float64
#  4   weight                    3000 non-null   float64
#  5   cholesterol               3000 non-null   float64
#  6   systolic_blood_pressure   3000 non-null   int64
#  7   diastolic_blood_pressure  3000 non-null   int64
#  8   glucose                   3000 non-null   float64
#  9   bone_density              3000 non-null   float64
#  10  activity                  3000 non-null   object
#  11  smoke_status              3000 non-null   object
#  12  medical_history           1711 non-null   object
#  13  family_medical_history    1514 non-null   object
#  14  sleep_pattern             3000 non-null   object
#  15  edu_level                 2393 non-null   object
#  16  mean_working              1968 non-null   float64
#  17  stress_score              3000 non-null   float64
# dtypes: float64(7), int64(3), object(8)
# memory usage: 422.0+ KB

# %%
train.drop('ID',axis=1,inplace=True)
train['mean_working'].fillna(0,inplace=True)

train
# Out:
# /var/folders/q1/wy16nfjn4sn4s87yr7501dc40000gn/T/ipykernel_61860/949774650.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['mean_working'].fillna(0,inplace=True)
#      gender  age  height  weight  cholesterol  systolic_blood_pressure  \
# 0         F   72  161.49   58.47       279.84                      165
# 1         M   88  179.87   77.60       257.37                      178
# 2         M   47  182.47   89.93       226.66                      134
# 3         M   69  185.78   68.63       206.74                      158
# 4         F   81  164.63   71.53       255.92                      171
# ...     ...  ...     ...     ...          ...                      ...
# 2995      F   87  174.43   77.14       233.31                      176
# 2996      M   25  171.44   51.67       196.89                      143
# 2997      F   54  162.13   55.54       210.52                      164
# 2998      M   70  181.32   82.20       234.10                      182
# 2999      M   86  179.46   69.31       254.63                      149
#
#       diastolic_blood_pressure  glucose  bone_density  activity  \
# 0                          100   143.35          0.87  moderate
# 1                          111   146.94          0.07  moderate
# 2                           95   142.61          1.18     light
# 3                           92   137.26          0.48   intense
# 4                          116   129.37          0.34  moderate
# ...                        ...      ...           ...       ...
# 2995                       111   134.71          0.20     light
# 2996                        86   111.91          1.75  moderate
# 2997                        91   136.47          0.80     light
# 2998                        91   144.89          0.58  moderate
# 2999                        94   154.92          0.45  moderate
#
#         smoke_status      medical_history family_medical_history  \
# 0          ex-smoker  high blood pressure               diabetes
# 1          ex-smoker                  NaN               diabetes
# 2          ex-smoker                  NaN                    NaN
# 3          ex-smoker  high blood pressure                    NaN
# 4          ex-smoker             diabetes               diabetes
# ...              ...                  ...                    ...
# 2995      non-smoker                  NaN                    NaN
# 2996  current-smoker                  NaN                    NaN
# 2997  current-smoker                  NaN                    NaN
# 2998      non-smoker                  NaN                    NaN
# 2999       ex-smoker  high blood pressure          heart disease
#
#          sleep_pattern            edu_level  mean_working  stress_score
# 0     sleep difficulty     bachelors degree           0.0          0.63
# 1               normal      graduate degree           0.0          0.83
# 2               normal  high school diploma           9.0          0.70
# 3         oversleeping      graduate degree           0.0          0.17
# 4     sleep difficulty     bachelors degree           0.0          0.36
# ...                ...                  ...           ...           ...
# 2995      oversleeping                  NaN           0.0          0.02
# 2996            normal  high school diploma           9.0          0.16
# 2997            normal                  NaN           9.0          0.16
# 2998      oversleeping  high school diploma           0.0          0.18
# 2999            normal                  NaN           0.0          0.04
#
# [3000 rows x 17 columns]

# %%
sns.barplot(data=train,x='gender',y='stress_score',hue='')
